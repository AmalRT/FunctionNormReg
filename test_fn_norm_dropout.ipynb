# %% [markdown]
# Test Function norm vs. Dropout
# =========================================================
#
# Architecture:
#
#         self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
#         self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
#         if self.useDropout:
#             self.conv2_drop = nn.Dropout2d()
#         self.fc1 = nn.Linear(320, 50)
#         self.fc2 = nn.Linear(50, 10)
#
# VAE: Vanilla VAE 784 -> 128 -> 100
#
# Regularization samples = 2x training samples
#
# $\lambda =$ 0.1

# %%
from __future__ import print_function, division
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
import os
import os.path as osp
from pytorch_utils import StatsLogger
from itertools import product

# %%
basedir = ['/esat/kochab/arannen/Pytorch_fun_regularization_generation1/MNIST_300_'+str(i)+'_Net' for i in range(1,11)]
basedir
# Out:
# ['/esat/kochab/arannen/Pytorch_fun_regularization_generation1/MNIST_300_1_Net',
#  '/esat/kochab/arannen/Pytorch_fun_regularization_generation1/MNIST_300_2_Net',
#  '/esat/kochab/arannen/Pytorch_fun_regularization_generation1/MNIST_300_3_Net',
#  '/esat/kochab/arannen/Pytorch_fun_regularization_generation1/MNIST_300_4_Net',
#  '/esat/kochab/arannen/Pytorch_fun_regularization_generation1/MNIST_300_5_Net',
#  '/esat/kochab/arannen/Pytorch_fun_regularization_generation1/MNIST_300_6_Net',
#  '/esat/kochab/arannen/Pytorch_fun_regularization_generation1/MNIST_300_7_Net',
#  '/esat/kochab/arannen/Pytorch_fun_regularization_generation1/MNIST_300_8_Net',
#  '/esat/kochab/arannen/Pytorch_fun_regularization_generation1/MNIST_300_9_Net',
#  '/esat/kochab/arannen/Pytorch_fun_regularization_generation1/MNIST_300_10_Net']

# %% [markdown]
# =========================================================================================================
# Without function norm:
# ============================================================

# %%
w = (0,0.0005)
b = (True, False)

# %%
expnames = {}
for k in range(1,11):
    s = product((False,),b,b,w)
    expnames[k] = ['MNIST_300_'+str(k)+'_Net_'+str(i[0])+'_'+str(i[1])+'_'+str(i[2])+'_'+str(i[3]) for i in list(s)]

# %%
expdirs = {}
expnames_kept = {}
for k in range(1,11):
    expdirs[k] = []
    expnames_kept[k] = []
    for exp in expnames[k]:
        this = 0
        b = True
        try:
            while b:
                this -= 1
                if osp.isdir(osp.join(basedir[k-1], exp)):
                    last = sorted(os.listdir(osp.join(basedir[k-1], exp)), key=int)[this]
                    expdir = osp.join(basedir[k-1], exp, last)
                    if osp.isfile(osp.join(expdir, "stats.pkl")):
                        expdirs[k].append(expdir)
                        expnames_kept[k].append(exp)
                        print(exp + ": loading", last)
                        break
                else:
                    b = False

        except IndexError:
            continue
        
expnames = expnames_kept
# Out:
# MNIST_300_1_Net_False_False_True_0: loading 10000
# MNIST_300_1_Net_False_False_True_0.0005: loading 10000
# MNIST_300_1_Net_False_False_False_0: loading 10000
# MNIST_300_1_Net_False_False_False_0.0005: loading 10000
# MNIST_300_2_Net_False_False_True_0: loading 10000
# MNIST_300_2_Net_False_False_True_0.0005: loading 10000
# MNIST_300_2_Net_False_False_False_0: loading 10000
# MNIST_300_2_Net_False_False_False_0.0005: loading 10000
# MNIST_300_3_Net_False_False_True_0: loading 10000
# MNIST_300_3_Net_False_False_True_0.0005: loading 10000
# MNIST_300_3_Net_False_False_False_0: loading 10000
# MNIST_300_3_Net_False_False_False_0.0005: loading 10000
# MNIST_300_4_Net_False_False_True_0: loading 10000
# MNIST_300_4_Net_False_False_True_0.0005: loading 10000
# MNIST_300_4_Net_False_False_False_0: loading 10000
# MNIST_300_4_Net_False_False_False_0.0005: loading 10000
# MNIST_300_5_Net_False_False_True_0: loading 10000
# MNIST_300_5_Net_False_False_True_0.0005: loading 10000
# MNIST_300_5_Net_False_False_False_0: loading 10000
# MNIST_300_5_Net_False_False_False_0.0005: loading 10000
# MNIST_300_6_Net_False_False_True_0: loading 10000
# MNIST_300_6_Net_False_False_True_0.0005: loading 10000
# MNIST_300_6_Net_False_False_False_0: loading 10000
# MNIST_300_6_Net_False_False_False_0.0005: loading 10000
# MNIST_300_7_Net_False_False_True_0: loading 10000
# MNIST_300_7_Net_False_False_True_0.0005: loading 10000
# MNIST_300_7_Net_False_False_False_0: loading 10000
# MNIST_300_7_Net_False_False_False_0.0005: loading 10000
# MNIST_300_8_Net_False_False_True_0: loading 10000
# MNIST_300_8_Net_False_False_True_0.0005: loading 10000
# MNIST_300_8_Net_False_False_False_0: loading 10000
# MNIST_300_8_Net_False_False_False_0.0005: loading 10000
# MNIST_300_9_Net_False_False_True_0: loading 10000
# MNIST_300_9_Net_False_False_True_0.0005: loading 10000
# MNIST_300_9_Net_False_False_False_0: loading 10000
# MNIST_300_9_Net_False_False_False_0.0005: loading 10000
# MNIST_300_10_Net_False_False_True_0: loading 10000
# MNIST_300_10_Net_False_False_True_0.0005: loading 10000
# MNIST_300_10_Net_False_False_False_0: loading 10000
# MNIST_300_10_Net_False_False_False_0.0005: loading 10000

# %%
stats = {}
for k in range(1,11):
    stats[k] = []
    for expdir in expdirs[k]:
        stats[k].append(StatsLogger(expdir))

# %%
curves  = {}
for k in range(1,11):
    curves[k] = []
    for a in stats[k]:
        c = a.curve('Accuracy','test')
        curves[k].append(c)

# %%
w = (0,0.0005)
b = (True, False)
s = product((False,),(False,),b,w)
expdisp = [str(i[0])+'_'+str(i[1])+'_'+str(i[2])+'_'+str(i[3]) for i in list(s)]

plt.figure(figsize=(15, 10))

for i in range(4):
    cx = np.zeros((len(curves[1][0].x),10))
    cy = np.zeros((len(curves[1][0].y),10))
    for k in range(1,11):
        cx[:,k-1]= np.array(curves[k][i].x)
        cy[:,k-1]= np.array(curves[k][i].y) 
    plt.plot(cx.mean(1), cy.mean(1), "o-", label=expdisp[i])
    # legend = b1_b2_b3_c: b1 = Function norm or not; b2 = Batch norm. or not; b3 = Dropout or not; c = weight decay
plt.legend()
plt.xlabel('iter')
# Out:
# Text(0.5,0,u'iter')

# %% [markdown]
# =========================================================================================================
# With function norm:
# ============================================================

# %%
w = (0,0.0005)
b = (True, False)

# %%
expnames = {}
for k in range(1,11):
    s = product((True,),b,b,w)
    expnames[k] = ['MNIST_300_'+str(k)+'_Net_'+str(i[0])+'_'+str(i[1])+'_'+str(i[2])+'_'+str(i[3]) for i in list(s)]

# %%
expdirs = {}
expnames_kept = {}
for k in range(1,11):
    expdirs[k] = []
    expnames_kept[k] = []
    for exp in expnames[k]:
        this = 0
        b = True
        try:
            while b:
                this -= 1
                if osp.isdir(osp.join(basedir[k-1], exp)):
                    last = sorted(os.listdir(osp.join(basedir[k-1], exp)), key=int)[this]
                    expdir = osp.join(basedir[k-1], exp, last)
                    if osp.isfile(osp.join(expdir, "stats.pkl")):
                        expdirs[k].append(expdir)
                        expnames_kept[k].append(exp)
                        print(exp + ": loading", last)
                        break
                else:
                    b = False

        except IndexError:
            continue
        
expnames = expnames_kept
# Out:
# MNIST_300_1_Net_True_False_True_0: loading 10000
# MNIST_300_1_Net_True_False_True_0.0005: loading 10000
# MNIST_300_1_Net_True_False_False_0: loading 10000
# MNIST_300_1_Net_True_False_False_0.0005: loading 10000
# MNIST_300_2_Net_True_False_True_0: loading 10000
# MNIST_300_2_Net_True_False_True_0.0005: loading 10000
# MNIST_300_2_Net_True_False_False_0: loading 10000
# MNIST_300_2_Net_True_False_False_0.0005: loading 10000
# MNIST_300_3_Net_True_False_True_0: loading 10000
# MNIST_300_3_Net_True_False_True_0.0005: loading 10000
# MNIST_300_3_Net_True_False_False_0: loading 10000
# MNIST_300_3_Net_True_False_False_0.0005: loading 10000
# MNIST_300_4_Net_True_False_True_0: loading 10000
# MNIST_300_4_Net_True_False_True_0.0005: loading 10000
# MNIST_300_4_Net_True_False_False_0: loading 10000
# MNIST_300_4_Net_True_False_False_0.0005: loading 10000
# MNIST_300_5_Net_True_False_True_0: loading 10000
# MNIST_300_5_Net_True_False_True_0.0005: loading 10000
# MNIST_300_5_Net_True_False_False_0: loading 10000
# MNIST_300_5_Net_True_False_False_0.0005: loading 10000
# MNIST_300_6_Net_True_False_True_0: loading 10000
# MNIST_300_6_Net_True_False_True_0.0005: loading 10000
# MNIST_300_6_Net_True_False_False_0: loading 10000
# MNIST_300_6_Net_True_False_False_0.0005: loading 10000
# MNIST_300_7_Net_True_False_True_0: loading 10000
# MNIST_300_7_Net_True_False_True_0.0005: loading 10000
# MNIST_300_7_Net_True_False_False_0: loading 10000
# MNIST_300_7_Net_True_False_False_0.0005: loading 10000
# MNIST_300_8_Net_True_False_True_0: loading 10000
# MNIST_300_8_Net_True_False_True_0.0005: loading 10000
# MNIST_300_8_Net_True_False_False_0: loading 10000
# MNIST_300_8_Net_True_False_False_0.0005: loading 10000
# MNIST_300_9_Net_True_False_True_0: loading 10000
# MNIST_300_9_Net_True_False_True_0.0005: loading 10000
# MNIST_300_9_Net_True_False_False_0: loading 10000
# MNIST_300_9_Net_True_False_False_0.0005: loading 10000
# MNIST_300_10_Net_True_False_True_0: loading 10000
# MNIST_300_10_Net_True_False_True_0.0005: loading 10000
# MNIST_300_10_Net_True_False_False_0: loading 10000
# MNIST_300_10_Net_True_False_False_0.0005: loading 10000

# %%
stats = {}
for k in range(1,11):
    stats[k] = []
    for expdir in expdirs[k]:
        stats[k].append(StatsLogger(expdir))

# %%
curves  = {}
for k in range(1,11):
    curves[k] = []
    for a in stats[k]:
        c = a.curve('Accuracy','test')
        curves[k].append(c)

# %%
w = (0,0.0005)
b = (True, False)
s = product((True,),(False,),b,w)
expdisp = [str(i[0])+'_'+str(i[1])+'_'+str(i[2])+'_'+str(i[3]) for i in list(s)]

plt.figure(figsize=(15, 10))

for i in range(4):
    cx = np.zeros((len(curves[1][0].x),10))
    cy = np.zeros((len(curves[1][0].y),10))
    for k in range(1,11):
        cx[:,k-1]= np.array(curves[k][i].x)
        cy[:,k-1]= np.array(curves[k][i].y) 
    plt.plot(cx.mean(1), cy.mean(1), "o-", label=expdisp[i])
    # legend = b1_b2_b3_c: b1 = Function norm or not; b2 = Batch norm. or not; b3 = Dropout or not; c = weight decay

plt.legend()
plt.xlabel('iter')
# Out:
# Text(0.5,0,u'iter')

# %% [markdown]
# =========================================================================================================
# With Dropout:
# ============================================================

# %%
w = (0,0.0005)
b = (True, False)

# %%
expnames = {}
for k in range(1,11):
    s = product(b,b,(True,),w)
    expnames[k] = ['MNIST_300_'+str(k)+'_Net_'+str(i[0])+'_'+str(i[1])+'_'+str(i[2])+'_'+str(i[3]) for i in list(s)]

# %%
expdirs = {}
expnames_kept = {}
for k in range(1,11):
    expdirs[k] = []
    expnames_kept[k] = []
    for exp in expnames[k]:
        this = 0
        b = True
        try:
            while b:
                this -= 1
                if osp.isdir(osp.join(basedir[k-1], exp)):
                    last = sorted(os.listdir(osp.join(basedir[k-1], exp)), key=int)[this]
                    expdir = osp.join(basedir[k-1], exp, last)
                    if osp.isfile(osp.join(expdir, "stats.pkl")):
                        expdirs[k].append(expdir)
                        expnames_kept[k].append(exp)
                        print(exp + ": loading", last)
                        break
                else:
                    b = False

        except IndexError:
            continue
        
expnames = expnames_kept
# Out:
# MNIST_300_1_Net_True_False_True_0: loading 10000
# MNIST_300_1_Net_True_False_True_0.0005: loading 10000
# MNIST_300_1_Net_False_False_True_0: loading 10000
# MNIST_300_1_Net_False_False_True_0.0005: loading 10000
# MNIST_300_2_Net_True_False_True_0: loading 10000
# MNIST_300_2_Net_True_False_True_0.0005: loading 10000
# MNIST_300_2_Net_False_False_True_0: loading 10000
# MNIST_300_2_Net_False_False_True_0.0005: loading 10000
# MNIST_300_3_Net_True_False_True_0: loading 10000
# MNIST_300_3_Net_True_False_True_0.0005: loading 10000
# MNIST_300_3_Net_False_False_True_0: loading 10000
# MNIST_300_3_Net_False_False_True_0.0005: loading 10000
# MNIST_300_4_Net_True_False_True_0: loading 10000
# MNIST_300_4_Net_True_False_True_0.0005: loading 10000
# MNIST_300_4_Net_False_False_True_0: loading 10000
# MNIST_300_4_Net_False_False_True_0.0005: loading 10000
# MNIST_300_5_Net_True_False_True_0: loading 10000
# MNIST_300_5_Net_True_False_True_0.0005: loading 10000
# MNIST_300_5_Net_False_False_True_0: loading 10000
# MNIST_300_5_Net_False_False_True_0.0005: loading 10000
# MNIST_300_6_Net_True_False_True_0: loading 10000
# MNIST_300_6_Net_True_False_True_0.0005: loading 10000
# MNIST_300_6_Net_False_False_True_0: loading 10000
# MNIST_300_6_Net_False_False_True_0.0005: loading 10000
# MNIST_300_7_Net_True_False_True_0: loading 10000
# MNIST_300_7_Net_True_False_True_0.0005: loading 10000
# MNIST_300_7_Net_False_False_True_0: loading 10000
# MNIST_300_7_Net_False_False_True_0.0005: loading 10000
# MNIST_300_8_Net_True_False_True_0: loading 10000
# MNIST_300_8_Net_True_False_True_0.0005: loading 10000
# MNIST_300_8_Net_False_False_True_0: loading 10000
# MNIST_300_8_Net_False_False_True_0.0005: loading 10000
# MNIST_300_9_Net_True_False_True_0: loading 10000
# MNIST_300_9_Net_True_False_True_0.0005: loading 10000
# MNIST_300_9_Net_False_False_True_0: loading 10000
# MNIST_300_9_Net_False_False_True_0.0005: loading 10000
# MNIST_300_10_Net_True_False_True_0: loading 10000
# MNIST_300_10_Net_True_False_True_0.0005: loading 10000
# MNIST_300_10_Net_False_False_True_0: loading 10000
# MNIST_300_10_Net_False_False_True_0.0005: loading 10000

# %%
stats = {}
for k in range(1,11):
    stats[k] = []
    for expdir in expdirs[k]:
        stats[k].append(StatsLogger(expdir))

# %%
curves  = {}
for k in range(1,11):
    curves[k] = []
    for a in stats[k]:
        c = a.curve('Accuracy','test')
        curves[k].append(c)

# %%
w = (0,0.0005)
b = (True, False)
s = product(b,(False,),(True,),w)
expdisp = [str(i[0])+'_'+str(i[1])+'_'+str(i[2])+'_'+str(i[3]) for i in list(s)]

plt.figure(figsize=(15, 10))

for i in range(4):
    cx = np.zeros((len(curves[1][0].x),10))
    cy = np.zeros((len(curves[1][0].y),10))
    for k in range(1,11):
        cx[:,k-1]= np.array(curves[k][i].x)
        cy[:,k-1]= np.array(curves[k][i].y) 
    plt.plot(cx.mean(1), cy.mean(1), "o-", label=expdisp[i])
    # legend = b1_b2_b3_c: b1 = Function norm or not; b2 = Batch norm. or not; b3 = Dropout or not; c = weight decay
    
plt.legend()
plt.xlabel('iter')
# Out:
# Text(0.5,0,u'iter')

# %% [markdown]
# =========================================================================================================
# Without Dropout:
# ============================================================

# %%
w = (0,0.0005)
b = (True, False)

# %%
expnames = {}
for k in range(1,11):
    s = product(b,b,(False,),w)
    expnames[k] = ['MNIST_300_'+str(k)+'_Net_'+str(i[0])+'_'+str(i[1])+'_'+str(i[2])+'_'+str(i[3]) for i in list(s)]

# %%
expdirs = {}
expnames_kept = {}
for k in range(1,11):
    expdirs[k] = []
    expnames_kept[k] = []
    for exp in expnames[k]:
        this = 0
        b = True
        try:
            while b:
                this -= 1
                if osp.isdir(osp.join(basedir[k-1], exp)):
                    last = sorted(os.listdir(osp.join(basedir[k-1], exp)), key=int)[this]
                    expdir = osp.join(basedir[k-1], exp, last)
                    if osp.isfile(osp.join(expdir, "stats.pkl")):
                        expdirs[k].append(expdir)
                        expnames_kept[k].append(exp)
                        print(exp + ": loading", last)
                        break
                else:
                    b = False

        except IndexError:
            continue
        
expnames = expnames_kept
# Out:
# MNIST_300_1_Net_True_False_False_0: loading 10000
# MNIST_300_1_Net_True_False_False_0.0005: loading 10000
# MNIST_300_1_Net_False_False_False_0: loading 10000
# MNIST_300_1_Net_False_False_False_0.0005: loading 10000
# MNIST_300_2_Net_True_False_False_0: loading 10000
# MNIST_300_2_Net_True_False_False_0.0005: loading 10000
# MNIST_300_2_Net_False_False_False_0: loading 10000
# MNIST_300_2_Net_False_False_False_0.0005: loading 10000
# MNIST_300_3_Net_True_False_False_0: loading 10000
# MNIST_300_3_Net_True_False_False_0.0005: loading 10000
# MNIST_300_3_Net_False_False_False_0: loading 10000
# MNIST_300_3_Net_False_False_False_0.0005: loading 10000
# MNIST_300_4_Net_True_False_False_0: loading 10000
# MNIST_300_4_Net_True_False_False_0.0005: loading 10000
# MNIST_300_4_Net_False_False_False_0: loading 10000
# MNIST_300_4_Net_False_False_False_0.0005: loading 10000
# MNIST_300_5_Net_True_False_False_0: loading 10000
# MNIST_300_5_Net_True_False_False_0.0005: loading 10000
# MNIST_300_5_Net_False_False_False_0: loading 10000
# MNIST_300_5_Net_False_False_False_0.0005: loading 10000
# MNIST_300_6_Net_True_False_False_0: loading 10000
# MNIST_300_6_Net_True_False_False_0.0005: loading 10000
# MNIST_300_6_Net_False_False_False_0: loading 10000
# MNIST_300_6_Net_False_False_False_0.0005: loading 10000
# MNIST_300_7_Net_True_False_False_0: loading 10000
# MNIST_300_7_Net_True_False_False_0.0005: loading 10000
# MNIST_300_7_Net_False_False_False_0: loading 10000
# MNIST_300_7_Net_False_False_False_0.0005: loading 10000
# MNIST_300_8_Net_True_False_False_0: loading 10000
# MNIST_300_8_Net_True_False_False_0.0005: loading 10000
# MNIST_300_8_Net_False_False_False_0: loading 10000
# MNIST_300_8_Net_False_False_False_0.0005: loading 10000
# MNIST_300_9_Net_True_False_False_0: loading 10000
# MNIST_300_9_Net_True_False_False_0.0005: loading 10000
# MNIST_300_9_Net_False_False_False_0: loading 10000
# MNIST_300_9_Net_False_False_False_0.0005: loading 10000
# MNIST_300_10_Net_True_False_False_0: loading 10000
# MNIST_300_10_Net_True_False_False_0.0005: loading 10000
# MNIST_300_10_Net_False_False_False_0: loading 10000
# MNIST_300_10_Net_False_False_False_0.0005: loading 10000

# %%
stats = {}
for k in range(1,11):
    stats[k] = []
    for expdir in expdirs[k]:
        stats[k].append(StatsLogger(expdir))

# %%
curves  = {}
for k in range(1,11):
    curves[k] = []
    for a in stats[k]:
        c = a.curve('Accuracy','test')
        curves[k].append(c)

# %%
w = (0,0.0005)
b = (True, False)
s = product(b,(False,),(False,),w)
expdisp = [str(i[0])+'_'+str(i[1])+'_'+str(i[2])+'_'+str(i[3]) for i in list(s)]

plt.figure(figsize=(15, 10))

for i in range(4):
    cx = np.zeros((len(curves[1][0].x),10))
    cy = np.zeros((len(curves[1][0].y),10))
    for k in range(1,11):
        cx[:,k-1]= np.array(curves[k][i].x)
        cy[:,k-1]= np.array(curves[k][i].y) 
    plt.plot(cx.mean(1), cy.mean(1), "o-", label=expdisp[i])
    # legend = b1_b2_b3_c: b1 = Function norm or not; b2 = Batch norm. or not; b3 = Dropout or not; c = weight decay
    
plt.legend()
plt.xlabel('iter')
# Out:
# Text(0.5,0,u'iter')
